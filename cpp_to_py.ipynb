# %%
# https://github.com/facebookresearch/CodeGen/blob/main/docs/transcoder.md
# https://github.com/facebookresearch/CodeGen/tree/main

# %%
# Note: if you really want the output of models to be exactly right, you need to change the constant  -
# - LAYER_NORM_EPSILON (codegen_sources/model/src/model/transformer.py) to be 1e-12 instead of 1e-5.

# %%
# !python -m codegen_sources.model.translate --gpu True --src_lang cpp --tgt_lang python --model_path codegen_sources/TransCoder_model_2.pth --beam_size 1 < modules/c_src_formatted.cpp
#!python -m codegen_sources.model.translate --gpu False --src_lang cpp --tgt_lang python --model_path codegen_sources/TransCoder_model_2.pth --beam_size 1 < modules/c_src_formatted.cpp
# Out:
# adding to path /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46
# No efficient attention.
# Using /home/na/data/CodeGen/code_evaluation/tmp_tests_folder for temporary files.
# adding to path /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46
# adding to path /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46
# adding to path /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46
# adding to path /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46
# INFO - 08/02/23 12:26:00 - 0:00:00 - Adding default value False for apex in parameter
# INFO - 08/02/23 12:26:00 - 0:00:00 - Adding default value 0.0 for layer_dropout in parameter
# INFO - 08/02/23 12:26:00 - 0:00:00 - Adding default value 2 for min_layers in parameter
# INFO - 08/02/23 12:26:00 - 0:00:00 - Adding default value False for cape_embeddings in parameter
# INFO - 08/02/23 12:26:00 - 0:00:00 - Adding default value 5.0 for cape_global_shift in parameter
# INFO - 08/02/23 12:26:00 - 0:00:00 - Adding default value 0.5 for cape_local_shift in parameter
# ...

# %%
# cannot import name 'tokenize_v14_international' from 'sacrebleu' =>
# install sacrebleu==1.2.11


# AssertionError: The path to the BPE tokens is incorrect: =>
# shift data folder to the specified location.


# AssertionError: /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/tree-sitter/tree-sitter-cpp =>
# https://github.com/tree-sitter/tree-sitter-cpp

# RuntimeError: CUDA error: CUBLAS_STATUS_NOT_INITIALIZED when calling `cublasCreate(handle)` =>
# OOM (out of memory) 


# IndexError: index out of range in self =>
# Model and data exist on different devices (CPUs, GPUs, TPUs).

# %%
# model/src/model/transformer.py =>
# N_MAX_POSITIONS = 1024
